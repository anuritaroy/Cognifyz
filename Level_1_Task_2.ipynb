# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("C:\\Users\\amiro\\Desktop\\Internship cognifiz\\Dataset .csv")

# %%
# Display the first few rows to verify loading
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Select numerical columns
numerical_cols = ['Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
# Calculate basic statistics
stats = df[numerical_cols].describe()

# %%
print(stats)
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
# Add median explicitly (describe() includes mean, std, etc., but median is the 50% mark)
stats.loc['median'] = df[numerical_cols].median()

# %%
print(stats)
# Out:
#         Average Cost for two  Price range  Aggregate rating         Votes
# count            9551.000000  9551.000000       9551.000000   9551.000000
# mean             1199.210763     1.804837          2.666370    156.909748
# std             16121.183073     0.905609          1.516378    430.169145
# min                 0.000000     1.000000          0.000000      0.000000
# 25%               250.000000     1.000000          2.500000      5.000000
# 50%               400.000000     2.000000          3.200000     31.000000
# 75%               700.000000     2.000000          3.700000    131.000000
# max            800000.000000     4.000000          4.900000  10934.000000
# median            400.000000     2.000000          3.200000     31.000000

# %%
# Display the statistics
print("Basic Statistical Measures for Numerical Columns:")
print(stats)
# Out:
# Basic Statistical Measures for Numerical Columns:
#         Average Cost for two  Price range  Aggregate rating         Votes
# count            9551.000000  9551.000000       9551.000000   9551.000000
# mean             1199.210763     1.804837          2.666370    156.909748
# std             16121.183073     0.905609          1.516378    430.169145
# min                 0.000000     1.000000          0.000000      0.000000
# 25%               250.000000     1.000000          2.500000      5.000000
# 50%               400.000000     2.000000          3.200000     31.000000
# 75%               700.000000     2.000000          3.700000    131.000000
# max            800000.000000     4.000000          4.900000  10934.000000
# median            400.000000     2.000000          3.200000     31.000000

# %%
#Visualize distributions with histograms
plt.figure(figsize=(12, 8))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Country Code distribution
country_dist = df['Country Code'].value_counts(normalize=True) * 100  # Percentage
print("\nCountry Code Distribution (%):")
print(country_dist)
# Out:
# Country Code Distribution (%):
# Country Code
# 1      90.587373
# 216     4.544027
# 215     0.837609
# 30      0.628206
# 214     0.628206
# 189     0.628206
# 148     0.418804
# 208     0.355984
# 14      0.251283
# 162     0.230342
# 94      0.219872
# 184     0.209402
# 166     0.209402
# 191     0.209402
# 37      0.041880
# Name: proportion, dtype: float64

# %%
# Visualize
plt.figure(figsize=(10, 6))
sns.barplot(x=country_dist.index, y=country_dist.values)
plt.title('Distribution of Country Code')
plt.xlabel('Country Code')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45)
plt.show()

# %%
# City distribution (top 10 for clarity)
city_dist = df['City'].value_counts().head(10)  # Top 10 cities
print("\nTop 10 Cities by Restaurant Count:")
print(city_dist)
# Out:
# Top 10 Cities by Restaurant Count:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: count, dtype: int64

# %%
# Visualize
plt.figure(figsize=(10, 6))
sns.barplot(x=city_dist.index, y=city_dist.values)
plt.title('Top 10 Cities by Restaurant Count')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)
plt.show()

# %%
# Split cuisines and count individual occurrences
cuisines_series = df['Cuisines'].dropna().str.split(', ').explode()
cuisine_dist = cuisines_series.value_counts().head(10)  # Top 10 cuisines
print("\nTop 10 Cuisines by Frequency:")
print(cuisine_dist)
# Out:
# Top 10 Cuisines by Frequency:
# Cuisines
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Mughlai          995
# Italian          764
# Bakery           745
# Continental      736
# Cafe             703
# Desserts         653
# South Indian     636
# Name: count, dtype: int64

# %%
# Visualize
plt.figure(figsize=(10, 6))
sns.barplot(x=cuisine_dist.index, y=cuisine_dist.values)
plt.title('Top 10 Cuisines by Frequency')
plt.xlabel('Cuisine')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
# Top 5 Cities
top_cities = df['City'].value_counts().head(5)
print("\nTop 5 Cities with the Highest Number of Restaurants:")
print(top_cities)
# Out:
# Top 5 Cities with the Highest Number of Restaurants:
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: count, dtype: int64

# %%
# Top 5 Cuisines
top_cuisines = cuisines_series.value_counts().head(5)
print("\nTop 5 Cuisines:")
print(top_cuisines)
# Out:
# Top 5 Cuisines:
# Cuisines
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Mughlai          995
# Italian          764
# Name: count, dtype: int64
